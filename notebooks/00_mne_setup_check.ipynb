# %% [markdown]
# # 00 — MNE Setup Check
#
# This notebook checks that the NeuroSignalLab Python environment can import the core packages needed for EEG loading, visualization, preprocessing, and analysis.

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import sklearn
import mne

print("Python:", sys.version)
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("scikit-learn:", sklearn.__version__)
print("MNE:", mne.__version__)
# Out:
# Python: 3.13.6 (v3.13.6:4e665351082, Aug  6 2025, 11:22:35) [Clang 16.0.0 (clang-1600.0.26.6)]
# NumPy: 2.5.2
# Pandas: 3.0.5
# Matplotlib: 3.11.1
# scikit-learn: 1.9.0
# MNE: 1.12.1

# %%
mne.set_log_level("WARNING")
print("MNE setup check complete.")
# Out:
# MNE setup check complete.

# %%
example_shape = (10, 64, 640)
example_shape
# Out:
# (10, 64, 640)

# %% [markdown]
# The shape `(10, 64, 640)` represents 10 EEG epochs, 64 EEG channels, and 640 time samples per epoch.
#
# For the PhysioNet motor-imagery dataset, the sampling frequency is 160 Hz, so a 4-second epoch would contain:
#
# `160 samples/second × 4 seconds = 640 time samples`.
